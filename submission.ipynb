# %%
import pandas as pd

# %%
df = pd.read_csv('2019_winter_ds_challenge_dataset.csv')

# %%
df[df['order_amount']==330]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 159        160       73      725           330            2          debit
# 227        228       73      917           330            2          debit
# 267        268       73      790           330            2    credit_card
# 802        803       73      863           330            2          debit
# 1128      1129       73      981           330            2          debit
# 1261      1262       73      791           330            2          debit
# 1488      1489       73      898           330            2    credit_card
# 1576      1577       73      923           330            2    credit_card
# 1632      1633       73      834           330            2           cash
# 1633      1634       73      942           330            2           cash
# 2074      2075       73      794           330            2    credit_card
# ...

# %%
df.describe()
# Out:
#           order_id      shop_id      user_id   order_amount  total_items
# count  5000.000000  5000.000000  5000.000000    5000.000000   5000.00000
# mean   2500.500000    50.078800   849.092400    3145.128000      8.78720
# std    1443.520003    29.006118    87.798982   41282.539349    116.32032
# min       1.000000     1.000000   607.000000      90.000000      1.00000
# 25%    1250.750000    24.000000   775.000000     163.000000      1.00000
# 50%    2500.500000    50.000000   849.000000     284.000000      2.00000
# 75%    3750.250000    75.000000   925.000000     390.000000      3.00000
# max    5000.000000   100.000000   999.000000  704000.000000   2000.00000

# %%
df['total_items'].value_counts()
# Out:
# 2       1832
# 1       1830
# 3        941
# 4        293
# 5         77
# 2000      17
# 6          9
# 8          1
# Name: total_items, dtype: int64

# %%
df[df['total_items']==2000]
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 60          61       42      607        704000         2000    credit_card
# 520        521       42      607        704000         2000    credit_card
# 1104      1105       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# 1436      1437       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# ...

# %%
df[df['total_items']==2000]['created_at'].value_counts()
# Out:
# 2017-03-28 4:00:00    3
# 2017-03-02 4:00:00    2
# 2017-03-07 4:00:00    2
# 2017-03-24 4:00:00    2
# 2017-03-15 4:00:00    1
# 2017-03-11 4:00:00    1
# 2017-03-17 4:00:00    1
# 2017-03-25 4:00:00    1
# 2017-03-12 4:00:00    1
# 2017-03-22 4:00:00    1
# 2017-03-04 4:00:00    1
# 2017-03-19 4:00:00    1
# Name: created_at, dtype: int64

# %% [markdown]
# ### Shop_id user_id order_amount total_items payment_method are all the same. Created at is the same at some orders. I consider those systematic problem in orders.

# %%
sum(df['order_amount']/df['total_items'])/len(df)
# Out:
# 387.7428
